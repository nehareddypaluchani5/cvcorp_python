# %%
#return

def great(a,b):
    if a>b:
        return a
    else:
        return b
print(great(75,77))
# Out:
# 77

# %%
def fun(*a):
    return sum(a)
x= fun(1,2,34,56,7)
if x%2==0:
    print(f"even :{x}")
else:
    print(f"odd : {x} ")
# Out:
# even :100

# %%
def fun1(x,y):
    print(x+y)
r=fun1
print(r(10,45))
k=r(77,80)
print(k)
# Out:
# 55
# None
# 157
# None

# %%
#format
name= input("enter  a number :")
s= f"name :{name}"
print(s)
# Out:
# name :Neha Reddy Paluchani

# %%
a=10
k=f"a:{a}"
print(k)
a=30
print(k)
# Out:
# a:10
# a:10
