# %%
from numpy.distutils.fcompiler import none
from setuptools import namespaces

from Functions import students


class Student:
    """Just a student class"""
    total = 0
    def  __init__(self, name, age):
        self.name = name
        self.age = age
        Student.total +=1

    def display(self, phno,Branch):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")
        print(f"Branch: {Branch}")
        print(f"Phone: {phno}")
        self.total_students()

    @classmethod
    def total_students(cls):
        print(f"Total Students: {cls.total}")

    @classmethod
    def change(cls,n):
        cls.total = n

    @staticmethod
    def just(name, age):
        if len(name) < 10 and age < 18:
            print("Name too short and age must be greater than 18")
        else:
            print("Valid credentials")



s1 = Student("John", 25)
s2 = Student("Michael", 35)
s3 = Student("Bob", 35)

s1.display(2345678,"CSE")
print()
Student.display(s1,5678998765,"CSE")
Student.total_students()
Student.change(20)
s1.change(25)
s1.total_students()
Student.total_students()
Student.just("Michael", 35)
s1.just("Michael", 20)

s1.total += 1
print(s1.total)
print(s2.total)
print(s3.total)
print(Student.total)

print(s1.__dict__)
print(s2.__dict__)
print(s3.__dict__)

print(Student.__dict__)
# Out:
# Name: John
# Age: 25
# Branch: CSE
# Phone: 2345678
# Total Students: 3
#
# Name: John
# Age: 25
# Branch: CSE
# Phone: 5678998765
# Total Students: 3
# Total Students: 3
# Total Students: 25
# Total Students: 25
# Valid credentials
# Valid credentials
# 26
# 25
# 25
# 25
# {'name': 'John', 'age': 25, 'total': 26}
# {'name': 'Michael', 'age': 35}
# {'name': 'Bob', 'age': 35}
# {'__module__': '__main__', '__doc__': 'Just a student class', 'total': 25, '__init__': <function Student.__init__ at 0x000001647143E160>, 'display': <function Student.display at 0x000001647143E200>, 'total_students': <classmethod(<function Student.total_students at 0x000001647143E2A0>)>, 'change': <classmethod(<function Student.change at 0x000001647143E340>)>, 'just': <staticmethod(<function Student.just at 0x000001647143E3E0>)>, '__dict__': <attribute '__dict__' of 'Student' objects>, '__weakref__': <attribute '__weakref__' of 'Student' objects>}

# %%
# 10 thhh Question

class Student:
    passing_marks = 40
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def result(self):
        if self.marks >= Student.passing_marks:
            print(f"{self.name} : pass")
        else:
            print(f"{self.name} : fail")

    @classmethod
    def update(cls,pm):
        cls.passing_marks = pm

    @staticmethod
    def grade_category(m):
        if m >= 90:
            return "A"
        elif m >= 80:
            return "B"
        elif m >= 70:
            return "C"
        elif m >= 60:
            return "D"
        else:
            return "F"


s1 = Student("Jaya simha", 99)
s2 = Student("sohail", 98)
s3 = Student("Ganesh", 35)
s4 = Student("RK", 96)

s1.result()
s2.result()
s3.result()
s4.result()

s3.update(99)
s1.marks = 9
s3.marks = 100
s1.result()
s2.result()
s3.result()
s4.result()


print(s1.grade_category(s1.marks))
# Out:
# Jaya simha : pass
# sohail : pass
# Ganesh : fail
# RK : pass
# Jaya simha : fail
# sohail : fail
# Ganesh : pass
# RK : fail
# F

# %%
#7th Question
class Employee:
    bonus_rate=0.1
    def __init__(self,name,base_salary):
        self.name=name
        self.base_salary=base_salary
    def final_salary(self):
        return self.base_salary +(self.base_salary * Employee. bonus_rate)
    @classmethod
    def update_bonus(cls,new_rate):
        cls.bonus_rate =new_rate
    @staticmethod
    def is_valid_salary(sal):
        return sal>0
s1=Employee("Neha",100000)
s2=Employee("Karthikeya",200000)
print(s1.final_salary())
print(s2.final_salary())
s1.update_bonus(0.3)
print(s1.final_salary())
print(s2.final_salary())
# Out:
# 110000.0
# 220000.0
# 130000.0
# 260000.0

# %%
#6th Question
class Book:
    total_books=0
    def __init__(self,title,author):
        self.title=title
        self.author=author
        Book.total_books+=1
    @classmethod
    def from_string(cls,book_str):
        title,author=book_str.split("-")
        if cls.valid_title(title):
            return cls(title,author)
        else:
            return None
    @staticmethod
    def valid_title(title):
        return len(title)>=3

bts="harry Potter-Jk Rowling"
b1=Book.from_string(bts)
b2=Book("the song if ice and fire","RR.MArtin")

# %%
#1 question
class Student:
    def  __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def is_passed(self):
        return self.marks>40
e1=Student("Neha",36)
e2=Student("Chinni",76)
if e1.is_passed():
    print(e1.name,"passed")
else:
    print(e1.name,"Failed")
if e2.is_passed():
    print(e2.name,"Passed")
else:
    print(e2.name,"Failed")
# Out:
# Neha Failed
# Chinni Passed

# %%
#2 Question
class Employee:
    company_name="TechCorp"
    def __init__(self,name ):
        self.name=name
    @classmethod
    def change_company(cls,new_name):
        cls.company_name = new_name

E1=Employee("neha")
E2=Employee("Meghana")
print("Before Changing company")
print(E1.name,"-",E1.company_name)
print(E2.name,"-",E1.company_name)
print("After Changing company")
Employee.change_company("Google")
print(E1.name,"-",E1.company_name)
print(E2.name,"-",E2.company_name)
# Out:
# Before Changing company
# neha - TechCorp
# Meghana - TechCorp
# After Changing company
# neha - Google
# Meghana - Google

# %%
#3 Question
class MathOps:
    @staticmethod
    def is_even(num):
        return num%2==0
print(MathOps.is_even(12))
print(MathOps.is_even(21))
# Out:
# True
# False

# %%
#4 Question
class Car:
    wheels=4
    def __init__(self,mileage):
        self.mileage=mileage
    def display_spec(self):
        print("Mileage",self.mileage)
        print("Wheels",Car.wheels)
    @classmethod
    def change_wheels(cls,new_wheels):
        cls.wheels=new_wheels
print("Before changing wheels")
c1=Car(20)
c1.display_spec()
c1.change_wheels(6)
print("After Changing wheels")
c1.display_spec()
# Out:
# Before changing wheels
# Mileage 20
# Wheels 4
# After Changing wheels
# Mileage 20
# Wheels 6

# %%
#5 question
class Temperature:
    def __init__(self,celsius):
        self.celsius=celsius
    @staticmethod
    def to_fahrenheit(celsius):
         return (celsius * 9/5) + 32

    def show_conversion(self):
        fahrenheit = Temperature.to_fahrenheit(self.celsius)
        print("Celsius:", self.celsius, "°C")
        print("Fahrenheit:", fahrenheit, "°F")
temp = Temperature(25)
temp.show_conversion()
# Out:
# Celsius: 25 °C
# Fahrenheit: 77.0 °F

# %%
#8 question
class Course:
    total_students=0
    def __init__(self,student_name):
        self.student_name=student_name
    def enroll(self):
        Course.total_students+=1
    @classmethod
    def show_total(cls):
        print("total students",cls.total_students)
    @staticmethod
    def is_eligible(age):
        return age>=18
C1=Course("Neha")
C2=Course("Ritvik")
C1.enroll()
C2.enroll()
C1.show_total()
print("Neha Eligible",Course.is_eligible(21))
print("Ritvik Eligible",Course.is_eligible(26))
# Out:
# total students 2
# Neha Eligible True
# Ritvik Eligible True

# %%
#9 Question
class BankAccount:
    bank_name= "IndianBank"
    def __init__(self,holder,balance):
        self.holder=holder
        self.balance=balance
    def deposit(self,amount):
        if BankAccount.validate_amount(amount):
            self.balance += amount
            print("Amount Deposited:", amount)
            print("New Balance:", self.balance)
        else:
            print("Invalid amount!")
    @classmethod
    def change_bank_name(cls,new_name):
         cls.bank_name= new_name
    @staticmethod
    def validate_amount(amount):
        return amount>0
b1=BankAccount("Neha",5000)
b2=BankAccount("Vamsi",3000)
print("Bank Name:", BankAccount.bank_name)
b1.deposit(1000)
b2.deposit(-150)
BankAccount.change_bank_name("ICICI Bank")

print("\nAfter changing bank name:")
print(b1.holder, "-", b1.bank_name)
print(b2.holder, "-", b2.bank_name)
# Out:
# Bank Name: IndianBank
# Amount Deposited: 1000
# New Balance: 6000
# Invalid amount!
#
# After changing bank name:
# Neha - ICICI Bank
# Vamsi - ICICI Bank
