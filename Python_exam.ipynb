# %% [markdown]
# <h1>1 question</h1>

# %%
temps = [2, 31, 40, 44, 62, 11, 1]xs
result = sorted(filter(lambda c: c > 0 and c % 5 != 0,map(lambda f: (f - 32) * 5 / 9, temps)),key=lambda x: x % 3)
print(result)
# Out:
# [6.666666666666667, 4.444444444444445, 16.666666666666668]

# %% [markdown]
#  <h1>3 Question</h1>

# %%
double = lambda x: x * 2
triple = lambda x: x * 3
quadruple = lambda x: x * 4
funcs = [double, triple, quadruple]
def apply_all(func, value):
    for func in funcs:
        value = func(value)
    return value
print(apply_all(funcs, 123935))
# Out:
# 2974440

# %% [markdown]
# <h1> 2 Question</h1>

# %%
company_budget= 500000
def company_tracker():
    total_projects=100
    def updated_projects():
        #nonlocal total_projects
        global company_budget
        total_projects=total_projects+20
        company_budget+=100000
        print("updated total project:",total_projects)
        print("updated company budget:",company_budget)
    updated_projects()


company_tracker()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 14
#      10         print("updated company budget:",company_budget)
#      11     updated_projects()
#      12
#      13
# ---> 14 company_tracker()
#
# Cell In[6], line 11, in company_tracker()
#       7         total_projects=total_projects+20
#       8         company_budget+=100000
#       9         print("updated total project:",total_projects)
#      10         print("updated company budget:",company_budget)
# ---> 11     updated_projects()
#
# Cell In[6], line 7, in company_tracker.<locals>.updated_projects()
#       4     def updated_projects():
#       5         #nonlocal total_projects
#       6         global company_budget
# ----> 7         total_projects=total_projects+20
#       8         company_budget+=100000
#       9         print("updated total project:",total_projects)
# ...

# %%
def fun():
    x=50
    def fun2():
        print(x)
    fun2()
fun()
# Out:
# 50
