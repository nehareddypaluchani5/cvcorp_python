# %%
import operator
from math import remainder

# 1. Program to convert kg to grams

kg = float(input("enter the value :"))
grams =int( kg*1000)
print(f"weight in grams :{grams}g")
# Out:
# weight in grams :12000g

# %%
# program to covert temperature from degree C to F.
c =float(input("enter the value :"))
f = (c*9/5)+32
print(f"temperture of F :{f}f")
# Out:
# temperture of F :253.4f

# %%
# 3. Program to find the biggest among 3 numbers
a,b,c=20,300,40
if a>b and a>c:
    print("biggest number is:",a)
elif b>a and b>c:
    print("biggest numbet is :",b)
else:
    print("biggest number is :",c)
# Out:
# biggest numbet is : 300

# %%
num=280
if num>=100 and num<=1000:
    if num%2==0:
       print("even number")
       remainder = num%3
       print("remainder when 3 is divided :",remainder)
    else:
       print("odd number")
       remainder = num%2
       print("remainder  when 2 is divided :",remainder)
else:
      print("wrong number")
# Out:
# even number
# remainder when 3 is divided : 1

# %%
i=int(input("enter the number"))
if i<0 or i>100:
   print("invalid input")
else:
    if(i>=90 and i<100):
        print("super smart")
    elif(i>=81 and i<90):
        print("smart")
    elif(i>=71 and i<80):
        print("smart enough")
    elif(i>=61 and i<70):
        print("just smart")
    elif(i>=36 and i<60):
        print("no smart")
    else:
        print("dump")
# Out:
# invalid input

# %%
a=int(input("enter a number"))
b=int(input("enter b number"))
operator=input("enter the operator")
if operator == "+":
    print("result :",a+b)
elif operator == "-":
    print("result :",a-b)
elif operator == "*":
    print("result :",a*b)
elif operator == "/":
    print("result :",a/b)
else:
    print("invaild input")
# Out:
# invaild input

# %%
n=int(input("enter a valuee"))
for i in range(1,n+1):
    print("CVCORP")
# Out:
# CVCORP
# CVCORP
# CVCORP
# CVCORP

# %%
for i in range(250,550):
    if i%11==0:
        print(i)
# Out:
# 253
# 264
# 275
# 286
# 297
# 308
# 319
# 330
# 341
# 352
# 363
# 374
# 385
# 396
# 407
# 418
# 429
# 440
# 451
# 462
# 473
# 484
# 495
# 506
# 517
# 528
# 539

# %%
sum=0
for i in range(56,153):
    sum=sum +i
print("sum is :",sum)
# Out:
# sum is : 10088

# %%
for i in range(70,90):
    if i%2==0:
       print(i)
# Out:
# 70
# 72
# 74
# 76
# 78
# 80
# 82
# 84
# 86
# 88

# %%
~~~~year = int(input("Enter year: "))

if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print("Leap Year")
else:
    print("Not Leap Year")
# Out:
# Leap Year
